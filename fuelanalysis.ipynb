# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
fuel_data = pd.read_csv(r"C:\Users\GLORIA\Downloads\fuel_ferc1.csv")

# %%
fuel_data
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
fuel_data.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
#checking if there are duplicated values
fuel_data.duplicated().any()
# Out:
# False

# %%
fuel_data['fuel_unit'].value_counts()
# Out:
# mcf       11354
# ton        8958
# bbl        7998
# gramsU      464
# mmbtu       180
# kgU         110
# mwhth       100
# mwdth        95
# gal          84
# Name: fuel_unit, dtype: int64

# %%
fuel_data.dropna()
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
fuel_data['fuel_type_code_pudl'].value_counts()
# Out:
# gas        11486
# coal        8547
# oil         8064
# nuclear      818
# waste        441
# other        167
# Name: fuel_type_code_pudl, dtype: int64

# %%
#checking for missing values
fuel_data.isnull().sum()
# Out:
# record_id                       0
# utility_id_ferc1                0
# report_year                     0
# plant_name_ferc1                0
# fuel_type_code_pudl             0
# fuel_unit                       0
# fuel_qty_burned                 0
# fuel_mmbtu_per_unit             0
# fuel_cost_per_unit_burned       0
# fuel_cost_per_unit_delivered    0
# fuel_cost_per_mmbtu             0
# dtype: int64

# %%
#sum of each unique value in fuel unit column
fuel_data.groupby('fuel_unit')['fuel_unit'].count()
#fuel_data[['fuel_unit']] = fuel_data[['fuel_unit']].fillna(value='mcf')
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11534
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
#assuming we want to investigate the quqntity of fuel burnt by year
ax = sns.lineplot(x='report_year', y='fuel_qty_burned', data= fuel_data)

# %%
#assuming we want to investigate the quantity of fuel and type of fuel burnt by year
ax = sns.lineplot(x='report_year', y='fuel_qty_burned', data= fuel_data, hue='fuel_type_code_pudl')

# %%
sns.set(rc={'figure.figsize':(12,10)})
ax = sns.lineplot(x='report_year', y='fuel_qty_burned', data= fuel_data, hue='fuel_type_code_pudl', style='fuel_type_code_pudl')

# %%
sns.set(rc={'figure.figsize':(12,10)})
ax = sns.lineplot(x='report_year', y='fuel_qty_burned', data= fuel_data, hue='fuel_type_code_pudl', ci= False)

# %%
sns.set(rc={'figure.figsize':(12,10)})
ax = sns.lineplot(x='report_year', y='fuel_qty_burned', data= fuel_data, hue='fuel_type_code_pudl', ci= False, markers= True)

# %%
#bar plot
ax = sns.barplot(x='report_year', y='fuel_qty_burned', data= fuel_data)
fuel_data[['fuel_qty_burned','report_year']].groupby('report_year').agg({'fuel_qty_burned':'mean'})
# Out:
#              fuel_qty_burned
# report_year
# 1994            2.724018e+06
# 1995            3.712067e+06
# 1996            2.544754e+06
# 1997            2.813503e+06
# 1998            3.267453e+06
# 1999            3.281281e+06
# 2000            2.472032e+06
# 2001            2.321402e+06
# 2002            2.145645e+06
# 2003            1.888622e+06
# 2004            1.782547e+06
# 2005            1.768876e+06
# 2006            1.957264e+06
# 2007            2.035696e+06
# 2008            2.046455e+06
# 2009            2.154993e+06
# 2010            2.423720e+06
# 2011            2.461332e+06
# 2012            2.747094e+06
# 2013            2.741505e+06
# 2014            2.700008e+06
# 2015            3.340131e+06
# 2016            3.693289e+06
# 2017            3.352850e+06
# 2018            4.178890e+06

# %%
ax = sns.barplot(x='report_year', y='fuel_qty_burned', data= fuel_data, ci= None)

# %%
#RELATIONSHIP BETWEEN FUEL TYPE AND FUEL BURNT
ax = sns.barplot(x='fuel_type_code_pudl', y='fuel_qty_burned', data= fuel_data, ci= None)

# %%
sns.set(rc={'figure.figsize':(12,10)})
ax = sns.barplot(x='fuel_type_code_pudl', y='fuel_qty_burned',hue='fuel_unit', data= fuel_data, ci= None)

# %%
fuel_data['fuel_type_code_pudl'].values
# Out:
# array(['coal', 'coal', 'coal', ..., 'gas', 'coal', 'gas'], dtype=object)

# %%
#x=fuel_data['fuel_type_code_pudl'].values
#sns.distplot(x)g = sns.barplot(data=fuel_unit, x='unit', y='count'
#g.set_yscale("log")
#g.set_ylim(1, 12000)
#plt.xlabel('Fuel Unit')

# %%
#correlation analysis

# %%
#fig, axis= subplots(2,2, figsize=(12,7))
fuel_data.columns
# Out:
# Index(['record_id', 'utility_id_ferc1', 'report_year', 'plant_name_ferc1',
#        'fuel_type_code_pudl', 'fuel_unit', 'fuel_qty_burned',
#        'fuel_mmbtu_per_unit', 'fuel_cost_per_unit_burned',
#        'fuel_cost_per_unit_delivered', 'fuel_cost_per_mmbtu'],
#       dtype='object')

# %%
sample_df = fuel_data.sample(n=50, random_state=4)
sns.regplot(x=sample_df["utility_id_ferc1"], y=sample_df["fuel_cost_per_unit_burned"], fit_reg=False)

# %%
sample_df = fuel_data.sample(n=50, random_state=4)
sns.lmplot(x='utility_id_ferc1', y='fuel_cost_per_mmbtu', height=5, data=fuel_data)
